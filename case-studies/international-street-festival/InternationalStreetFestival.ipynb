# %% [markdown]
# # International Street Festival

# %%
import sys
sys.path.append('../src/')

# %% [markdown]
# ## Read all sensor data

# %%
# Contains as key the sensor name and as value the complete data
from SmartCityHelper.Data import getAllSensors

sensorData = getAllSensors()

print(sensorData.keys())
# Out:
# dict_keys(['Brenzstr', 'FuZo_Eugen-Jaekle-Platz', 'FuZo_Olgastr', 'Arkaden', 'Knoepfle_Nord', 'Knoepfle_Ost'])

# %% [markdown]
# ## Visualize Sensors

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md

from SmartCityHelper.Filter import filterDateRange
from SmartCityHelper.Reducer import sumReducer, avgReducer, sumReducerWithReset
import datetime

# %%
### 2022

plt.subplots(figsize=(10, 6))
for sensorName, data in sensorData.items():
    dataPoints = dict(sorted(data['singleDataPoints'].items())).values()
    dataPointsStreetFestival = [d for d in dataPoints if filterDateRange(d, "2022-12-24 16:00:00", "2022-12-27 02:00:00")]
    dataPointsStreetFestival = sumReducerWithReset(dataPointsStreetFestival, 'person.in', ["2022-12-25 05:00:00", "2022-12-25 16:00:00", "2022-12-26 05:00:00", "2022-12-26 16:00:00"])
    #dataPointsStreetFestival = avgReducer(dataPointsStreetFestival, 'person.in', 2)

    x = []
    y = []

    for dataPoint in dataPointsStreetFestival:
        y.append(dataPoint['person.in'])
        datetimeValue = datetime.datetime.strptime(dataPoint['datetime'], '%Y-%m-%d %H:%M:%S')
        x.append(datetimeValue)

    plt.plot(x, y, label=sensorName)

#plt.ylim(0, 5000)
leg = plt.legend(loc='upper left')
plt.title("2022")

ax=plt.gca()
xfmt = md.DateFormatter('%d.%m %H:%M')
ax.xaxis.set_major_formatter(xfmt)
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.xticks(rotation=90)
plt.savefig('warten-aufs-christkind-2022.png', bbox_inches="tight")

### 2023

plt.subplots(figsize=(10, 6))
for sensorName, data in sensorData.items():
    dataPoints = dict(sorted(data['singleDataPoints'].items())).values()
    dataPointsStreetFestival = [d for d in dataPoints if filterDateRange(d, "2023-06-23 16:00:00", "2023-06-25 02:00:00")]
    dataPointsStreetFestival = sumReducerWithReset(dataPointsStreetFestival, 'person.in', ["2023-06-24 05:00:00", "2023-06-24 16:00:00"])
    #dataPointsStreetFestival = avgReducer(dataPointsStreetFestival, 'person.in', 2)

    x = []
    y = []

    for dataPoint in dataPointsStreetFestival:
        y.append(dataPoint['person.in'])
        datetimeValue = datetime.datetime.strptime(dataPoint['datetime'], '%Y-%m-%d %H:%M:%S')
        x.append(datetimeValue)

    plt.plot(x, y, label=sensorName)
    
#plt.ylim(0, 5000)
leg = plt.legend(loc='upper left')
plt.title("2023")

ax=plt.gca()
xfmt = md.DateFormatter('%d.%m %H:%M')
ax.xaxis.set_major_formatter(xfmt)
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.xticks(rotation=90)
plt.savefig('warten-aufs-christkind-2023.png', bbox_inches="tight")
plt.show()

# %% [markdown]
# # Get absoulte numbers:

# %%
for sensorName, data in sensorData.items():
    dataPoints = dict(sorted(data['singleDataPoints'].items())).values()
    dataPoints22 = [d for d in dataPoints if filterDateRange(d, "2022-12-23 20:30:00", "2022-12-24 05:00:00")]
    dataPoints22 = sumReducer(dataPoints22, 'person.in')

    print("2022 {0}: {1}".format(sensorName, dataPoints22[-1]['person.in']))

    dataPoints23 = [d for d in dataPoints if filterDateRange(d, "2023-12-23 20:30:00", "2023-12-24 05:00:00")]
    dataPoints23 = sumReducer(dataPoints23, 'person.in')
    
    print("2023 {0}: {1}".format(sensorName, dataPoints23[-1]['person.in']))
# Out:
# 2022 Brenzstr: 1041
# 2023 Brenzstr: 604
# 2022 FuZo_Eugen-Jaekle-Platz: 1885
# 2023 FuZo_Eugen-Jaekle-Platz: 2172
# 2022 FuZo_Olgastr: 2494
# 2023 FuZo_Olgastr: 796
# 2022 Arkaden: 276
# 2023 Arkaden: 58
# 2022 Knoepfle_Nord: 1377
# 2023 Knoepfle_Nord: 304
# 2022 Knoepfle_Ost: 147
# 2023 Knoepfle_Ost: 15

# %%
import folium
import random

# Create a folium map centered at a specific location
m = folium.Map(location=[48.67638280435713, 10.151585739252655], zoom_start=15, zoom_control=False)

# Add markers for each sensor
for sensorName, data in sensorData.items():
    
    #MAX_DELTA =  0.00009
    MAX_DELTA =  0.0002

    latitude = data['latitude'] + (random.uniform(0, 1) * MAX_DELTA) - (MAX_DELTA / 2)
    longitude = data['longitude'] + (random.uniform(0, 1) * MAX_DELTA) - (MAX_DELTA / 2)


    label = folium.Marker(
        location=[latitude, longitude],
        icon=folium.Icon(),
        tooltip=sensorName
    )
    label.add_to(m)

# Display the map
#m.save(outfile= "map_of_sensors.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76de3b40da6d640cee5a9d88ccbd1bb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76de3b40da6d640cee5a9d88ccbd1bb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76de3b40da6d640cee5a9d88ccbd1bb6 = L.map(
#                 &quot;map_76de3b40da6d640cee5a9d88ccbd1bb6&quot;,
#                 {
#                     center: [48.67638280435713, 10.151585739252655],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: false,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_405a7dd3fb66cffd6bd1633ea53315b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_405a7dd3fb66cffd6bd1633ea53315b2.addTo(map_76de3b40da6d640cee5a9d88ccbd1bb6);
#
#
#             var marker_c2476eb40beded52495aa30c8e1f3285 = L.marker(
#                 [48.67830870744803, 10.15195622813134],
#                 {}
#             ).addTo(map_76de3b40da6d640cee5a9d88ccbd1bb6);
#
#
#             var icon_39f13152040cb65663e768acbf4bd775 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2476eb40beded52495aa30c8e1f3285.setIcon(icon_39f13152040cb65663e768acbf4bd775);
#
#
#             marker_c2476eb40beded52495aa30c8e1f3285.bindTooltip(
#                 `&lt;div&gt;
#                      Brenzstr
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_acdb18ddca65edb58d3771050f5f5d16 = L.marker(
#                 [48.67833055827357, 10.15195188855606],
#                 {}
#             ).addTo(map_76de3b40da6d640cee5a9d88ccbd1bb6);
#
#
#             var icon_cb12789b6fe6bc56e05d53a658b87bfe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_acdb18ddca65edb58d3771050f5f5d16.setIcon(icon_cb12789b6fe6bc56e05d53a658b87bfe);
#
#
#             marker_acdb18ddca65edb58d3771050f5f5d16.bindTooltip(
#                 `&lt;div&gt;
#                      FuZo_Eugen-Jaekle-Platz
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8d3ccd859f8db4d1e81ce3b7897f2309 = L.marker(
#                 [48.67928312240129, 10.152486561068487],
#                 {}
#             ).addTo(map_76de3b40da6d640cee5a9d88ccbd1bb6);
#
#
#             var icon_218086b548f41430d34ed645c73f455c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8d3ccd859f8db4d1e81ce3b7897f2309.setIcon(icon_218086b548f41430d34ed645c73f455c);
#
#
#             marker_8d3ccd859f8db4d1e81ce3b7897f2309.bindTooltip(
#                 `&lt;div&gt;
#                      FuZo_Olgastr
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6df1a9938068c85f8a7385e163d3bc8b = L.marker(
#                 [48.67917534356972, 10.152394405315745],
#                 {}
#             ).addTo(map_76de3b40da6d640cee5a9d88ccbd1bb6);
#
#
#             var icon_beb695bc620d6bf3065b996d985bf5bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6df1a9938068c85f8a7385e163d3bc8b.setIcon(icon_beb695bc620d6bf3065b996d985bf5bc);
#
#
#             marker_6df1a9938068c85f8a7385e163d3bc8b.bindTooltip(
#                 `&lt;div&gt;
#                      Arkaden
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fdba1563ee44826c052f8f576c63321 = L.marker(
#                 [48.676368428971344, 10.151577608143622],
#                 {}
#             ).addTo(map_76de3b40da6d640cee5a9d88ccbd1bb6);
#
#
#             var icon_e6573ca0f4cc731e9cc140ccf817addf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
